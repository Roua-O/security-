# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\roua othmani\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
engineer=pd.read_csv("engineer_job.csv")

# %%
display(engineer)
# Out:
#            ID                                      Title  \
# 0    engineer                           Quality Engineer
# 1    engineer        Electrical and Electronics Engineer
# 2    engineer                        Electrical Engineer
# 3    engineer     Associate Engineer, Test Manufacturing
# 4    engineer  PHP Software Engineer - Jumia (Full Time)
# ..        ...                                        ...
# 398  engineer   Full-Stack Engineer - NextGen (.NET/Vue)
# 399  engineer     Network/Data Centre Engineer -Dispatch
# 400  engineer                               IOS Engineer
# 401  engineer             Software Engineering Team Lead
# 402  engineer                  Senior Analytics Engineer
#
#                                    Company Location                Date Posted
# 0                        Phillips-Medisize   Sokoto   PostedPosted 20 days ago
# 1    Hephzibah Integrated Technologies Ltd    Abuja   PostedPosted 25 days ago
# 2                 Romax properties Limited    Lagos   PostedPosted 11 days ago
# 3                                Celestica    Lagos   PostedPosted 14 days ago
# 4                                    Jumia  Nigeria  PostedPosted 30+ days ago
# ..                                     ...      ...                        ...
# 398                                   Deel    Lagos  PostedPosted 30+ days ago
# 399                    DeRisk Technologies    Lagos  PostedPosted 30+ days ago
# 400                  Kuda Technologies Ltd    Lagos  PostedPosted 30+ days ago
# 401                                 M-KOPA    Lagos  PostedPosted 30+ days ago
# 402                                 M-KOPA    Lagos  PostedPosted 30+ days ago
#
# [403 rows x 5 columns]

# %%
# Filter rows with 'engineer' in the job title
filtered_engineer=engineer[engineer['Title'].str.contains('engineer', case=False)]

# Display the filtered DataFrame
display(filtered_engineer)
# Out:
#            ID                                      Title  \
# 0    engineer                           Quality Engineer
# 1    engineer        Electrical and Electronics Engineer
# 2    engineer                        Electrical Engineer
# 3    engineer     Associate Engineer, Test Manufacturing
# 4    engineer  PHP Software Engineer - Jumia (Full Time)
# ..        ...                                        ...
# 398  engineer   Full-Stack Engineer - NextGen (.NET/Vue)
# 399  engineer     Network/Data Centre Engineer -Dispatch
# 400  engineer                               IOS Engineer
# 401  engineer             Software Engineering Team Lead
# 402  engineer                  Senior Analytics Engineer
#
#                                    Company Location                Date Posted
# 0                        Phillips-Medisize   Sokoto   PostedPosted 20 days ago
# 1    Hephzibah Integrated Technologies Ltd    Abuja   PostedPosted 25 days ago
# 2                 Romax properties Limited    Lagos   PostedPosted 11 days ago
# 3                                Celestica    Lagos   PostedPosted 14 days ago
# 4                                    Jumia  Nigeria  PostedPosted 30+ days ago
# ..                                     ...      ...                        ...
# 398                                   Deel    Lagos  PostedPosted 30+ days ago
# 399                    DeRisk Technologies    Lagos  PostedPosted 30+ days ago
# 400                  Kuda Technologies Ltd    Lagos  PostedPosted 30+ days ago
# 401                                 M-KOPA    Lagos  PostedPosted 30+ days ago
# 402                                 M-KOPA    Lagos  PostedPosted 30+ days ago
#
# [403 rows x 5 columns]

# %%
analyst=pd.read_csv("analysis_job.csv")

# %%
display(analyst)
# Out:
#           ID                                              Title  \
# 0    Analyst                                IT Business Analyst
# 1    Analyst                    Finance & International Analyst
# 2    Analyst                                   Business Analyst
# 3    Analyst                   Junior Corporate Finance Analyst
# 4    Analyst                                  Logistics Analyst
# ..       ...                                                ...
# 168  Analyst       Senior Business Analyst - Process Automation
# 169  Analyst                                     Credit Analyst
# 170  Analyst               Pipeline Conversion Analyst- Onitsha
# 171  Analyst  OFFICE SALES ANALYST/ REPRESENTATIVE- Ilupeju ...
# 172  Analyst  Quality Assurance/ Quality control Analyst (En...
#
#                                      Company       Location  \
# 0              Boston Scientific Corporation    Cross River
# 1                           ServeLead Global          Lagos
# 2                              Wise Soft Lab        Nigeria
# 3              The Impeccable Skills Company          Lagos
# 4                                    NoemDek          Lagos
# ..                                       ...            ...
# 168                    Kuda Technologies Ltd          Lagos
# 169                                   M-KOPA          Lagos
# 170                                Max Drive        Onitsha
# 171  West Africa Vocational Education (WAVE)          Lagos
# 172                     LEITUNG GATE LIMITED  Port Harcourt
#
#                     Date Posted
# 0       PostedPosted 4 days ago
# 1        PostedPosted 1 day ago
# 2     PostedPosted 30+ days ago
# 3                   PostedToday
# 4     PostedPosted 30+ days ago
# ..                          ...
# 168  EmployerActive 23 days ago
# 169     PostedPosted 6 days ago
# 170    PostedPosted 16 days ago
# 171   EmployerActive 5 days ago
# 172   EmployerActive 2 days ago
#
# [173 rows x 5 columns]

# %%
# Filter rows with ' analyst' in the job title
filtered_analyst=analyst[analyst['Title'].str.contains('analyst', case=False)]

# Display the filtered DataFrame
display(filtered_analyst)
# Out:
#           ID                                              Title  \
# 0    Analyst                                IT Business Analyst
# 1    Analyst                    Finance & International Analyst
# 2    Analyst                                   Business Analyst
# 3    Analyst                   Junior Corporate Finance Analyst
# 4    Analyst                                  Logistics Analyst
# ..       ...                                                ...
# 168  Analyst       Senior Business Analyst - Process Automation
# 169  Analyst                                     Credit Analyst
# 170  Analyst               Pipeline Conversion Analyst- Onitsha
# 171  Analyst  OFFICE SALES ANALYST/ REPRESENTATIVE- Ilupeju ...
# 172  Analyst  Quality Assurance/ Quality control Analyst (En...
#
#                                      Company       Location  \
# 0              Boston Scientific Corporation    Cross River
# 1                           ServeLead Global          Lagos
# 2                              Wise Soft Lab        Nigeria
# 3              The Impeccable Skills Company          Lagos
# 4                                    NoemDek          Lagos
# ..                                       ...            ...
# 168                    Kuda Technologies Ltd          Lagos
# 169                                   M-KOPA          Lagos
# 170                                Max Drive        Onitsha
# 171  West Africa Vocational Education (WAVE)          Lagos
# 172                     LEITUNG GATE LIMITED  Port Harcourt
#
#                     Date Posted
# 0       PostedPosted 4 days ago
# 1        PostedPosted 1 day ago
# 2     PostedPosted 30+ days ago
# 3                   PostedToday
# 4     PostedPosted 30+ days ago
# ..                          ...
# 168  EmployerActive 23 days ago
# 169     PostedPosted 6 days ago
# 170    PostedPosted 16 days ago
# 171   EmployerActive 5 days ago
# 172   EmployerActive 2 days ago
#
# [173 rows x 5 columns]

# %%
consultant=pd.read_csv("consulting_job.csv")

# %%
display(consultant)
# Out:
#             ID                                              Title  \
# 0   consultant  Consultant - Program Engagements Consultant - ...
# 1   consultant     Management Consultant (MC), Digital Technology
# 2   consultant  Lead Consultant - Orphans and Vulnerable Child...
# 3   consultant  People Transformation Senior Management Consul...
# 4   consultant                                      IT Consultant
# ..         ...                                                ...
# 77  consultant  Consultant- Manager for HR Workday Implementat...
# 78  consultant  Microsoft Dynamics 365 Business Central Senior...
# 79  consultant                       Experienced Audit Consultant
# 80  consultant                      Realtor Consultants /Trainees
# 81  consultant   Microsoft Business Applications Sales Consultant
#
#                                      Company Location  \
# 0                                Mercy Corps    Abuja
# 1                     Phillips Consulting NG    Lagos
# 2                              Navanti Group    Abuja
# 3                     Phillips Consulting NG    Lagos
# 4                            CAVIDEL LIMITED    Lagos
# ..                                       ...      ...
# 77                                  Deloitte    Lagos
# 78                             ITC WORLDWIDE    Lagos
# 79              Pedabo Professional Services    Lagos
# 80  REAL ESTATE DR'S ENTERPRISE(REDOC HOMES)    Lagos
# 81                             ITC WORLDWIDE    Lagos
#
#                   Date Posted
# 0   PostedPosted 30+ days ago
# 1     PostedPosted 5 days ago
# 2   PostedPosted 30+ days ago
# 3    PostedPosted 10 days ago
# 4   PostedPosted 30+ days ago
# ..                        ...
# 77  PostedPosted 30+ days ago
# 78  PostedPosted 30+ days ago
# 79  PostedPosted 30+ days ago
# 80  PostedPosted 30+ days ago
# 81  PostedPosted 30+ days ago
#
# [82 rows x 5 columns]

# %%
# Filter rows with 'consultant' in the job title
filtered_consultant= consultant[consultant['Title'].str.contains('consultant', case=False)]

# Display the filtered DataFrame
display(filtered_consultant)
# Out:
#             ID                                              Title  \
# 0   consultant  Consultant - Program Engagements Consultant - ...
# 1   consultant     Management Consultant (MC), Digital Technology
# 2   consultant  Lead Consultant - Orphans and Vulnerable Child...
# 3   consultant  People Transformation Senior Management Consul...
# 4   consultant                                      IT Consultant
# ..         ...                                                ...
# 77  consultant  Consultant- Manager for HR Workday Implementat...
# 78  consultant  Microsoft Dynamics 365 Business Central Senior...
# 79  consultant                       Experienced Audit Consultant
# 80  consultant                      Realtor Consultants /Trainees
# 81  consultant   Microsoft Business Applications Sales Consultant
#
#                                      Company Location  \
# 0                                Mercy Corps    Abuja
# 1                     Phillips Consulting NG    Lagos
# 2                              Navanti Group    Abuja
# 3                     Phillips Consulting NG    Lagos
# 4                            CAVIDEL LIMITED    Lagos
# ..                                       ...      ...
# 77                                  Deloitte    Lagos
# 78                             ITC WORLDWIDE    Lagos
# 79              Pedabo Professional Services    Lagos
# 80  REAL ESTATE DR'S ENTERPRISE(REDOC HOMES)    Lagos
# 81                             ITC WORLDWIDE    Lagos
#
#                   Date Posted
# 0   PostedPosted 30+ days ago
# 1     PostedPosted 5 days ago
# 2   PostedPosted 30+ days ago
# 3    PostedPosted 10 days ago
# 4   PostedPosted 30+ days ago
# ..                        ...
# 77  PostedPosted 30+ days ago
# 78  PostedPosted 30+ days ago
# 79  PostedPosted 30+ days ago
# 80  PostedPosted 30+ days ago
# 81  PostedPosted 30+ days ago
#
# [82 rows x 5 columns]

# %%
#DATA PROCESSING

# %%
filtered_engineer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           403 non-null    object
#  1   Title        403 non-null    object
#  2   Company      403 non-null    object
#  3   Location     403 non-null    object
#  4   Date Posted  403 non-null    object
# dtypes: object(5)
# memory usage: 15.9+ KB

# %%
filtered_consultant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           82 non-null     object
#  1   Title        82 non-null     object
#  2   Company      82 non-null     object
#  3   Location     82 non-null     object
#  4   Date Posted  82 non-null     object
# dtypes: object(5)
# memory usage: 3.3+ KB

# %%
filtered_analyst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           173 non-null    object
#  1   Title        173 non-null    object
#  2   Company      173 non-null    object
#  3   Location     173 non-null    object
#  4   Date Posted  173 non-null    object
# dtypes: object(5)
# memory usage: 6.9+ KB

# %%
#DATA CLEANING

# %%
missing_values=filtered_engineer.isnull().sum()

# %%
display("missing_values:", missing_values)
# Out:
# 'missing_values:'
# ID             0
# Title          0
# Company        0
# Location       0
# Date Posted    0
# dtype: int64

# %%
missing_values=filtered_analyst.isnull().sum()

# %%
display("missing_values:", missing_values)
# Out:
# 'missing_values:'
# ID             0
# Title          0
# Company        0
# Location       0
# Date Posted    0
# dtype: int64

# %%
filtered_analyst=filtered_analyst.dropna()

# %%
missing_values=filtered_consultant.isnull().sum()

# %%
display("missing_values:", missing_values)
# Out:
# 'missing_values:'
# ID             0
# Title          0
# Company        0
# Location       0
# Date Posted    0
# dtype: int64

# %%
filtered_engineer.to_csv("engineer_job.csv" , index=False)

# %%
filtered_analyst.to_csv("analysis_job.csv" , index=False)

# %%
filtered_consultant.to_csv("consulting_job.csv" , index=False)

# %%
#DATA CONCATINATING

# %%
all_jobs = pd.concat([filtered_engineer,filtered_analyst,filtered_consultant])

# %%
display(all_jobs)
# Out:
#             ID                                              Title  \
# 0     engineer                                   Quality Engineer
# 1     engineer                Electrical and Electronics Engineer
# 2     engineer                                Electrical Engineer
# 3     engineer             Associate Engineer, Test Manufacturing
# 4     engineer          PHP Software Engineer - Jumia (Full Time)
# ..         ...                                                ...
# 77  consultant  Consultant- Manager for HR Workday Implementat...
# 78  consultant  Microsoft Dynamics 365 Business Central Senior...
# 79  consultant                       Experienced Audit Consultant
# 80  consultant                      Realtor Consultants /Trainees
# 81  consultant   Microsoft Business Applications Sales Consultant
#
#                                      Company Location  \
# 0                          Phillips-Medisize   Sokoto
# 1      Hephzibah Integrated Technologies Ltd    Abuja
# 2                   Romax properties Limited    Lagos
# 3                                  Celestica    Lagos
# 4                                      Jumia  Nigeria
# ..                                       ...      ...
# 77                                  Deloitte    Lagos
# 78                             ITC WORLDWIDE    Lagos
# 79              Pedabo Professional Services    Lagos
# 80  REAL ESTATE DR'S ENTERPRISE(REDOC HOMES)    Lagos
# 81                             ITC WORLDWIDE    Lagos
#
#                   Date Posted
# 0    PostedPosted 20 days ago
# 1    PostedPosted 25 days ago
# 2    PostedPosted 11 days ago
# 3    PostedPosted 14 days ago
# 4   PostedPosted 30+ days ago
# ..                        ...
# 77  PostedPosted 30+ days ago
# 78  PostedPosted 30+ days ago
# 79  PostedPosted 30+ days ago
# 80  PostedPosted 30+ days ago
# 81  PostedPosted 30+ days ago
#
# [658 rows x 5 columns]

# %%
all_jobs.to_csv("all_jobss.csv" , index=False)

# %%
#EXTRACTED DATA ABALYSIS

# %%
#frequency of each job type
job_frequency = all_jobs['ID'].value_counts()

# %%
display(job_frequency)
# Out:
# ID
# engineer      403
# Analyst       173
# consultant     82
# Name: count, dtype: int64

# %%
# Plotting the job frequencies
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
job_frequency.plot(kind='bar')
plt.title('Frequency of Each Job Type')
plt.xlabel('Job Type')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines for y-axis
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Group data by ID
grouped = all_jobs.groupby('ID')

# Create a new figure for the plot
plt.figure(figsize=(15, 30))

# Loop through each group (ID)
for i, (name, group) in enumerate(grouped):
    # Count occurrences of each job title within the group
    job_counts = group['Title'].value_counts()
    # Select the top 10 job titles
    top_10_jobs = job_counts.head(10)
    # Plot the distribution of top 10 job titles for each ID
    plt.subplot(len(grouped), 1, i+1)
    top_10_jobs.plot(kind='bar', label=f'ID {name}')
    plt.title(f'Top 10 Jobs for ID {name}')
    plt.xlabel('Job Title')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Identify companies offering the most job opportunities
company_job_counts = all_jobs['Company'].value_counts().head(12)  # 12 the desired number of top companies
top_companies = company_job_counts.index.tolist()

# %%
# Calculate the percentage of each job title within each company
company_job_percentages = {}
for company in top_companies:
    total_jobs = all_jobs[all_jobs['Company'] == company]['ID'].count()
    job_titles = all_jobs[all_jobs['Company'] == company]['ID'].value_counts()
    company_job_percentages[company] = (job_titles / total_jobs) * 100
display(company_job_percentages[company] )
# Out:
# ID
# engineer    83.333333
# Analyst     16.666667
# Name: count, dtype: float64

# %%
 plt.subplots(2, 1, figsize=(15, 10))
# Out:
# (<Figure size 1500x1000 with 2 Axes>,
#  array([<Axes: >, <Axes: >], dtype=object))

# %%
# Plotting company job counts
plt.subplot(2, 1, 1)
company_job_counts.plot(kind='bar', color='skyblue')
plt.title('Top Companies by Job Opportunities')
plt.xlabel('Company')
plt.ylabel('Number of Job Opportunities')
# Out:
# Text(0, 0.5, 'Number of Job Opportunities')

# %%
# Define custom colors
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan', 'magenta', 'lime', 'pink', 'skyblue', 'yellow', 'brown']

#plot the distribution of job titles within each company
plt.figure(figsize=(12, 8))
for i, (company, job_percentages) in enumerate(company_job_percentages.items()):
    plt.bar(job_percentages.index, job_percentages.values, alpha=0.7, label=company, color=colors[i % len(colors)])

plt.title('Distribution of Job Titles within Top Companies (Percentage)')
plt.xlabel('Job Title')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Identify locations with the highest demand for roles
location_job_counts = all_jobs['Location'].value_counts().head(12)  # 12 number of top locations
top_locations = location_job_counts.index.tolist()

# %%
plt.figure(figsize=(15, 10))
# Plotting locations with the highest demand for roles
plt.subplot(2, 1, 1)
location_job_counts.plot(kind='bar', color='skyblue')
plt.title('Locations with the Highest Demand for Roles')
plt.xlabel('Location')
plt.ylabel('Number of Job Opportunities')
# Out:
# Text(0, 0.5, 'Number of Job Opportunities')
